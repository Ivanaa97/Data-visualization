# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fast')
data23 = pd.read_csv('/content/drive/MyDrive/Master/GenomeEngineering/Result23.csv')
data24 = pd.read_csv('/content/drive/MyDrive/Master/GenomeEngineering/Result24.csv')
dataWT = pd.read_csv('/content/drive/MyDrive/Master/GenomeEngineering/ResultWT.csv')
images_dir = '/content/drive/MyDrive/Master/GenomeEngineering'
#df = df.replace([','],value='.', regex=True)
#df = df.iloc[:,2:].astype(None)
data23
# Out:
#          Time      A      B      C      D      E
# 0     0:08:00  0.136  0.145  0.171  0.120  0.097
# 1     0:18:00  0.146  0.158  0.170  0.133  0.096
# 2     0:28:00  0.159  0.171  0.192  0.144  0.097
# 3     0:38:00  0.170  0.181  0.219  0.152  0.097
# 4     0:48:00  0.180  0.195  0.247  0.163  0.097
# ..        ...    ...    ...    ...    ...    ...
# 106  17:48:00  0.533  0.599  0.998  0.484  0.097
# 107  17:58:00  0.536  0.598  0.997  0.484  0.097
# 108  18:08:00  0.536  0.598  0.997  0.483  0.097
# 109  18:18:00  0.531  0.596  0.996  0.482  0.097
# 110  18:28:00  0.531  0.596  0.995  0.482  0.097
#
# [111 rows x 6 columns]

# %% [markdown]
# # **2+3**

# %%
x= np.arange(8, len(data23)*10,10)
plt.rc('xtick', labelsize=30)    # fontsize of the tick labels
plt.rc('ytick', labelsize=30)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"
plt.figure(figsize=(12.5,6.6))
plt.plot(x/60, data23['A'], ' ',color='k', marker='o', markersize=18,markerfacecolor="indigo")
plt.plot(x/60, data23['B'], ' ',color='k', marker='o', markersize=18,markerfacecolor="orange")
plt.plot(x/60, data23['C'], ' ',color='k', marker='o', markersize=18,markerfacecolor="mediumspringgreen")
plt.plot(x/60, data23['D'], ' ',color='k', marker='o', markersize=18,markerfacecolor="c")
plt.plot(x/60, data23['E'], ' ',color='k', marker='o', markersize=18,alpha=0.3, markerfacecolor="indigo")
plt.xlabel(r'Time (min)', family="serif",fontsize = 32)
plt.ylabel(r'$\log(\alpha_{growth})$', family="serif", fontsize = 32)
plt.title('2+3 in LB medium', fontsize = 30, family = 'sarif')
plt.xlabel(r'Time (h)', family="serif",fontsize = 32)
plt.ylabel(r'OD 600', family="serif", fontsize = 32)
#plt.legend(prop={"size":25, "family": "serif"},loc=(1.04,0))
plt.text(-1.8,1, '(a)', fontsize =50)
plt.ylim(0,1)
plt.xlim(0,10)
plt.grid()
plt.savefig(f"{images_dir}/23LB.png", bbox_inches="tight", dpi=100)

# %% [markdown]
# # **2+4**

# %%
x= np.arange(8, len(data24)*10,10)
plt.rc('xtick', labelsize=30)    # fontsize of the tick labels
plt.rc('ytick', labelsize=30)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"
plt.figure(figsize=(12.5,6.6))
plt.plot(x/60, data24['A'], ' ',color='k', marker='o', markersize=18,markerfacecolor="indigo")
plt.plot(x/60, data24['B'], ' ',color='k', marker='o', markersize=18,markerfacecolor="orange")
plt.plot(x/60, data24['C'], ' ',color='k', marker='o', markersize=18,markerfacecolor="mediumspringgreen")
plt.plot(x/60, data24['D'], ' ',color='k', marker='o', markersize=18,markerfacecolor="c")
plt.plot(x/60, data24['E'], ' ',color='k', marker='o', markersize=18,alpha=0.3, markerfacecolor="indigo")
plt.xlabel(r'Time (min)', family="serif",fontsize = 32)
plt.ylabel(r'$\log(\alpha_{growth})$', family="serif", fontsize = 32)
plt.title('2+4 in LB medium', fontsize = 30, family = 'sarif')
plt.xlabel(r'Time (h)', family="serif",fontsize = 32)
plt.ylabel(r'OD 600', family="serif", fontsize = 32)
#plt.legend(prop={"size":25, "family": "serif"},loc=(1.04,0))
plt.text(-1.8,1, '(b)', fontsize =50)
plt.ylim(0,1)
plt.xlim(0,10)
plt.grid()
plt.savefig(f"{images_dir}/24LB.png", bbox_inches="tight", dpi=100)

# %% [markdown]
# #**WT**

# %%
x= np.arange(8, len(dataWT)*10,10)
plt.rc('xtick', labelsize=30)    # fontsize of the tick labels
plt.rc('ytick', labelsize=30)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"
plt.figure(figsize=(12.5,6.6))
plt.plot(x/60, dataWT['A'], ' ',color='k', marker='o', markersize=18,markerfacecolor="indigo")
plt.plot(x/60, dataWT['B'], ' ',color='k', marker='o', markersize=18,markerfacecolor="orange")
plt.plot(x/60, dataWT['C'], ' ',color='k', marker='o', markersize=18,markerfacecolor="mediumspringgreen")
plt.plot(x/60, dataWT['D'], ' ',color='k', marker='o', markersize=18,markerfacecolor="c")
plt.plot(x/60, dataWT['E'], ' ',color='k', marker='o', markersize=18,alpha=0.3, markerfacecolor="indigo")
plt.xlabel(r'Time (min)', family="serif",fontsize = 32)
plt.ylabel(r'$\log(\alpha_{growth})$', family="serif", fontsize = 32)
plt.title('WT in LB medium', fontsize = 30, family = 'sarif')
plt.xlabel(r'Time (h)', family="serif",fontsize = 32)
plt.ylabel(r'OD 600', family="serif", fontsize = 32)
#plt.legend(prop={"size":25, "family": "serif"},loc=(1.04,0))
plt.text(-1.8,1, '(c)', fontsize =50)
plt.ylim(0,1)
plt.xlim(0,10)
plt.grid()
plt.savefig(f"{images_dir}/WTLB.png", bbox_inches="tight", dpi=100)

# %% [markdown]
# # **Log and linear regression**

# %%
Log_data23 = data23[:17]
Log_data23["Log23_A"] = np.log(Log_data23['A'])
Log_data23["Log23_B"] = np.log(Log_data23['B'])
Log_data23["Log23_C"] = np.log(Log_data23['C'])
Log_data23["Log23_D"] = np.log(Log_data23['D'])
Log_data23["Log23_E"] = np.log(Log_data23['E'])

Log_data24 = data24[:17]
Log_data24["Log24_A"] = np.log(Log_data24['A'])
Log_data24["Log24_B"] = np.log(Log_data24['B'])
Log_data24["Log24_C"] = np.log(Log_data24['C'])
Log_data24["Log24_D"] = np.log(Log_data24['D'])
Log_data24["Log24_E"] = np.log(Log_data24['E'])

Log_dataWT = dataWT[:17]
Log_dataWT["LogWT_A"] = np.log(Log_dataWT['A'])
Log_dataWT["LogWT_B"] = np.log(Log_dataWT['B'])
Log_dataWT["LogWT_C"] = np.log(Log_dataWT['C'])
Log_dataWT["LogWT_D"] = np.log(Log_dataWT['D'])
Log_dataWT["LogWT_E"] = np.log(Log_dataWT['E'])

# %% [markdown]
# ## **Log 2+3**

# %%
x= np.arange(8, len(Log_data23)*10,10)

#Optimization
from scipy.optimize import curve_fit 

#Fitting function
def func(x, a, b):
    return a*x+b
 
# Initial guess for the parameters
initialGuess = [1,1]    
 
#Perform the curve-fit
popt1, pcov1 = curve_fit(func, x/60,Log_data23["Log23_A"], initialGuess)
popt2, pcov2 = curve_fit(func, x/60,Log_data23["Log23_B"], initialGuess)
popt3, pcov3 = curve_fit(func, x/60,Log_data23["Log23_C"], initialGuess)
popt4, pcov4 = curve_fit(func, x/60,Log_data23["Log23_D"], initialGuess)
popt5, pcov5 = curve_fit(func, x/60,Log_data23["Log23_E"], initialGuess)
print('Slope 2+3 1: '+ str(popt1[0]) + '\n Y interset: '+ str(popt1[1]))
print('Slope 2+3 2: '+ str(popt2[0]) + '\n Y interset: '+ str(popt2[1]))
print('Slope 2+3 3: '+ str(popt3[0]) + '\n Y interset: '+ str(popt3[1]))
print('Slope 2+3 4: '+ str(popt4[0]) + '\n Y interset: '+ str(popt4[1]))
print('Slope 2+3 5: '+ str(popt5[0]) + '\n Y interset: '+ str(popt5[1]))

#Strain
S_23 = np.array([popt1[0],popt2[0],popt2[0],popt4[0]])

#x values for the fitted function
xFit = np.arange(0.0, 3.0, 0.01)
plt.figure(figsize=(12.5,6.6))

#Plot the fitted function
plt.plot(xFit, func(xFit, *popt1), color='indigo',lw=5.5)
plt.plot(xFit, func(xFit, *popt2), color='orange',lw=5.5)
plt.plot(xFit, func(xFit, *popt3), color='mediumspringgreen',lw=2.5)
plt.plot(xFit, func(xFit, *popt4), color='c',lw=2.5)
plt.plot(xFit, func(xFit, *popt5), color='k',lw=2.5)

plt.rc('xtick', labelsize=30)    # fontsize of the tick labels
plt.rc('ytick', labelsize=30)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"
plt.plot(x/60, Log_data23["Log23_A"], ' ',color='k', marker='o', markersize=25,alpha=1,markerfacecolor="indigo")
plt.plot(x/60, Log_data23["Log23_B"], ' ',color='k', marker='o', markersize=25,markerfacecolor="orange")
plt.plot(x/60, Log_data23["Log23_C"], ' ',color='k', marker='o', markersize=25,markerfacecolor="mediumspringgreen")
plt.plot(x/60, Log_data23["Log23_D"], ' ',color='k', marker='o', markersize=25,markerfacecolor="c")
plt.plot(x/60, Log_data23["Log23_E"], ' ',color='k', marker='o', markersize=25,alpha=0.3, markerfacecolor="indigo")

plt.xlabel(r'Time (min)', family="serif",fontsize = 32)
plt.ylabel(r'$\log(\alpha_{growth})$', family="serif", fontsize = 32)
plt.title('Logarithm OD600', fontsize = 30, family = 'sarif')
plt.xlabel(r'Time (h)', family="serif",fontsize = 32)
plt.ylabel(r'log(OD 600)', family="serif", fontsize = 32)
#plt.legend(prop={"size":25, "family": "serif"},loc=(1.04,0.74))
plt.grid()
plt.savefig(f"{images_dir}/23LB_log.png", bbox_inches="tight", dpi=100)
# Out:
# Slope 2+3 1: 0.5176083928382302
#  Y interset: -2.076064426695438
# Slope 2+3 2: 0.5452808850419268
#  Y interset: -2.0078697637974043
# Slope 2+3 3: 0.625659818012162
#  Y interset: -1.88949628824512
# Slope 2+3 4: 0.5224707648823398
#  Y interset: -2.1653753423003095
# Slope 2+3 5: 0.001066763312151024
#  Y interset: -2.3352184623780414

# %% [markdown]
# ## **Log 2+4**

# %%
x= np.arange(8, len(Log_data24)*10,10)

#Optimization
from scipy.optimize import curve_fit 

#Fitting function
def func(x, a, b):
    return a*x+b
 
# Initial guess for the parameters
initialGuess = [1,1]    
 
#Perform the curve-fit
popt1, pcov1 = curve_fit(func, x/60,Log_data24["Log24_A"], initialGuess)
popt2, pcov2 = curve_fit(func, x/60,Log_data24["Log24_B"], initialGuess)
popt3, pcov3 = curve_fit(func, x/60,Log_data24["Log24_C"], initialGuess)
popt4, pcov4 = curve_fit(func, x/60,Log_data24["Log24_D"], initialGuess)
popt5, pcov5 = curve_fit(func, x/60,Log_data24["Log24_E"], initialGuess)
print('Slope 2+3 1: '+ str(popt1[0]) + '\n Y interset: '+ str(popt1[1]))
print('Slope 2+3 2: '+ str(popt2[0]) + '\n Y interset: '+ str(popt2[1]))
print('Slope 2+3 3: '+ str(popt3[0]) + '\n Y interset: '+ str(popt3[1]))
print('Slope 2+3 4: '+ str(popt4[0]) + '\n Y interset: '+ str(popt4[1]))
print('Slope 2+3 5: '+ str(popt5[0]) + '\n Y interset: '+ str(popt5[1]))

#Strain
S_24 = np.array([popt1[0],popt2[0],popt5[0]])

#x values for the fitted function
xFit = np.arange(0.0, 3.0, 0.01)
plt.figure(figsize=(12.5,6.6))

#Plot the fitted function
plt.plot(xFit, func(xFit, *popt1), color='indigo',lw=5.5)
plt.plot(xFit, func(xFit, *popt2), color='orange',lw=5.5)
plt.plot(xFit, func(xFit, *popt3), color='mediumspringgreen',lw=2.5)
plt.plot(xFit, func(xFit, *popt4), color='c',lw=2.5)
plt.plot(xFit, func(xFit, *popt5), color='k',lw=2.5)

plt.rc('xtick', labelsize=30)    # fontsize of the tick labels
plt.rc('ytick', labelsize=30)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"
plt.plot(x/60, Log_data24["Log24_A"], ' ',color='k', marker='o', markersize=25,alpha=1,markerfacecolor="indigo")
plt.plot(x/60, Log_data24["Log24_B"], ' ',color='k', marker='o', markersize=25,markerfacecolor="orange")
plt.plot(x/60, Log_data24["Log24_C"], ' ',color='k', marker='o', markersize=25,markerfacecolor="mediumspringgreen")
plt.plot(x/60, Log_data24["Log24_D"], ' ',color='k', marker='o', markersize=25,markerfacecolor="c")
plt.plot(x/60, Log_data24["Log24_E"], ' ',color='k', marker='o', markersize=25,alpha=0.3, markerfacecolor="indigo")

plt.xlabel(r'Time (min)', family="serif",fontsize = 32)
plt.ylabel(r'$\log(\alpha_{growth})$', family="serif", fontsize = 32)
plt.title('Logarithm OD600', fontsize = 30, family = 'sarif')
plt.xlabel(r'Time (h)', family="serif",fontsize = 32)
plt.ylabel(r'log(OD 600)', family="serif", fontsize = 32)
#plt.legend(prop={"size":25, "family": "serif"},loc=(1.04,0.74))
plt.grid()
plt.savefig(f"{images_dir}/24LB_log.png", bbox_inches="tight", dpi=100)
# Out:
# Slope 2+3 1: 0.5319952954606915
#  Y interset: -2.1718658030833393
# Slope 2+3 2: 0.5220140870908327
#  Y interset: -2.0844120132384276
# Slope 2+3 3: -0.13080297494581755
#  Y interset: -1.6323113873987518
# Slope 2+3 4: -0.0010558192247469567
#  Y interset: -2.3302891218236326
# Slope 2+3 5: 0.5178159079611279
#  Y interset: -2.249017521759224

# %% [markdown]
# ## **Log WT**

# %%
x= np.arange(8, len(Log_dataWT)*10,10)

#Optimization
from scipy.optimize import curve_fit 

#Fitting function
def func(x, a, b):
    return a*x+b
 
# Initial guess for the parameters
initialGuess = [1,1]    
 
#Perform the curve-fit
popt1, pcov1 = curve_fit(func, x/60,Log_dataWT["LogWT_A"], initialGuess)
popt2, pcov2 = curve_fit(func, x/60,Log_dataWT["LogWT_B"], initialGuess)
popt3, pcov3 = curve_fit(func, x/60,Log_dataWT["LogWT_C"], initialGuess)
popt4, pcov4 = curve_fit(func, x/60,Log_dataWT["LogWT_D"], initialGuess)
popt5, pcov5 = curve_fit(func, x/60,Log_dataWT["LogWT_E"], initialGuess)
print('Slope 2+3 1: '+ str(popt1[0]) + '\n Y interset: '+ str(popt1[1]))
print('Slope 2+3 2: '+ str(popt2[0]) + '\n Y interset: '+ str(popt2[1]))
print('Slope 2+3 3: '+ str(popt3[0]) + '\n Y interset: '+ str(popt3[1]))
print('Slope 2+3 4: '+ str(popt4[0]) + '\n Y interset: '+ str(popt4[1]))
print('Slope 2+3 5: '+ str(popt5[0]) + '\n Y interset: '+ str(popt5[1]))

#Strain
S_WT = np.array([popt1[0],popt3[0],popt4[0]])

#x values for the fitted function
xFit = np.arange(0.0, 3.0, 0.01)
plt.figure(figsize=(12.5,6.6))

#Plot the fitted function
plt.plot(xFit, func(xFit, *popt1), color='indigo',lw=5.5)
plt.plot(xFit, func(xFit, *popt2), color='orange',lw=5.5)
plt.plot(xFit, func(xFit, *popt3), color='mediumspringgreen',lw=2.5)
plt.plot(xFit, func(xFit, *popt4), color='c',lw=2.5)
plt.plot(xFit, func(xFit, *popt5), color='k',lw=2.5)

plt.rc('xtick', labelsize=30)    # fontsize of the tick labels
plt.rc('ytick', labelsize=30)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"
plt.plot(x/60, Log_dataWT["LogWT_A"], ' ',color='k', marker='o', markersize=25,alpha=1,markerfacecolor="indigo")
plt.plot(x/60, Log_dataWT["LogWT_B"], ' ',color='k', marker='o', markersize=25,markerfacecolor="orange")
plt.plot(x/60, Log_dataWT["LogWT_C"], ' ',color='k', marker='o', markersize=25,markerfacecolor="mediumspringgreen")
plt.plot(x/60, Log_dataWT["LogWT_D"], ' ',color='k', marker='o', markersize=25,markerfacecolor="c")
plt.plot(x/60, Log_dataWT["LogWT_E"], ' ',color='k', marker='o', markersize=25,alpha=0.3, markerfacecolor="indigo")

plt.xlabel(r'Time (min)', family="serif",fontsize = 32)
plt.ylabel(r'$\log(\alpha_{growth})$', family="serif", fontsize = 32)
plt.title('Logarithm OD600', fontsize = 30, family = 'sarif')
plt.xlabel(r'Time (h)', family="serif",fontsize = 32)
plt.ylabel(r'log(OD 600)', family="serif", fontsize = 32)
#plt.legend(prop={"size":25, "family": "serif"},loc=(1.04,0.74))
plt.grid()
plt.savefig(f"{images_dir}/WTLB_log.png", bbox_inches="tight", dpi=100)
# Out:
# Slope 2+3 1: 0.49214499443762405
#  Y interset: -1.9348225448198701
# Slope 2+3 2: -0.02141299122498114
#  Y interset: -2.2562508115248536
# Slope 2+3 3: 0.5533264356706901
#  Y interset: -2.304525536800122
# Slope 2+3 4: 0.5654012243777344
#  Y interset: -2.234217649999877
# Slope 2+3 5: 0.15602391620348666
#  Y interset: -2.4023178293952023

# %% [markdown]
# # **Statistical test**

# %%
print(S_23,S_24,S_WT)
# Out:
# [0.51760839 0.54528089 0.54528089 0.52247076] [0.5319953  0.52201409 0.51781591] [0.49214499 0.55332644 0.56540122]
