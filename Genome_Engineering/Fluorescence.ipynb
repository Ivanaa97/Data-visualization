# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fast')
GFP1 = pd.read_csv('/content/drive/MyDrive/Master/GenomeEngineering/GFP1.csv')
GFP2 = pd.read_csv('/content/drive/MyDrive/Master/GenomeEngineering/GFP2.csv')
mkate1 = pd.read_csv('/content/drive/MyDrive/Master/GenomeEngineering/mkate1.csv')
mkate2= pd.read_csv('/content/drive/MyDrive/Master/GenomeEngineering/mkate2.csv')
images_dir = '/content/drive/MyDrive/Master/GenomeEngineering'

GFP1= GFP1.replace("OVRFLW",'0')
GFP2= GFP2.replace("OVRFLW",'0')
mkate1= mkate1.replace("OVRFLW",'0')
mkate2= mkate2.replace("OVRFLW",'0')

# %%
x = x= np.arange(8, len(Fluorescence1)*10,10)
fig = plt.figure(figsize=(30,32))
plt.rc('xtick', labelsize=30)    # fontsize of the tick labels
plt.rc('ytick', labelsize=30)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"
#LB 
ax1 = plt.subplot(321)
ax1.plot(x/60, Fluorescence1['B4'], ' ',color='k', marker='o', markersize=18,markerfacecolor="indigo")
#ax1.plot(x/60, Fluorescence2['B4'], ' ',color='k', marker='o', markersize=18,markerfacecolor="orange")
#ax1.plot(x/60, Fluorescence2['B6'], ' ',color='k', marker='o', markersize=18,markerfacecolor="mediumspringgreen")
ax1.plot(x/60, Fluorescence2['B9'], ' ',color='k', marker='o', markersize=18,markerfacecolor="c")
#ax1.plot(x/60, Fluorescence2['B10'], ' ',color='k', marker='o', markersize=18,alpha=0.3, markerfacecolor="indigo")
ax1.set_ylabel(r'Flourescence', family="serif",fontsize = 32)
ax1.set_xlabel(r'Time (h)', family="serif",fontsize = 32)
ax1.set_title('1+2 in LB', fontsize = 30, family = 'sarif')
ax1.grid()
ax1.set_ylim(0,40000)

#LB + Amp 
ax2 = plt.subplot(322)
ax2.plot(x/60, Fluorescence1['C4'], ' ',color='k', marker='o', markersize=18,markerfacecolor="indigo")
#ax2.plot(x/60, Fluorescence2['C4'], ' ',color='k', marker='o', markersize=18,markerfacecolor="orange")
#ax2.plot(x/60, Fluorescence2['C6'], ' ',color='k', marker='o', markersize=18,markerfacecolor="mediumspringgreen")
ax2.plot(x/60, Fluorescence2['C9'], ' ',color='k', marker='o', markersize=18,markerfacecolor="c")
#ax2.plot(x/60, Fluorescence2['C10'], ' ',color='k', marker='o', markersize=18,alpha=0.3, markerfacecolor="indigo")
ax2.set_ylabel(r'Flourescence', family="serif",fontsize = 32)
ax2.set_xlabel(r'Time (h)', family="serif",fontsize = 32)
ax2.set_title('1+2 in LB+Amp', fontsize = 30, family = 'sarif')
ax2.grid()
ax2.set_ylim(0,40000)

fig = plt.figure(figsize=(30,32))
#LB + Amp + Kan 
ax3 = plt.subplot(321)
plt.plot(x/60, Fluorescence1['D4'], ' ',color='k', marker='o', markersize=18,markerfacecolor="indigo")
#ax3t.plot(x/60, Fluorescence2['D4'], ' ',color='k', marker='o', markersize=18,markerfacecolor="orange")
#ax3t.plot(x/60, Fluorescence2['D6'], ' ',color='k', marker='o', markersize=18,markerfacecolor="mediumspringgreen")
ax3.plot(x/60, Fluorescence2['D9'], ' ',color='k', marker='o', markersize=18,markerfacecolor="c")
#ax3t.plot(x/60, Fluorescence2['D10'], ' ',color='k', marker='o', markersize=18,alpha=0.3, markerfacecolor="indigo")
ax3.set_ylabel(r'Flourescence', family="serif",fontsize = 32)
ax3.set_xlabel(r'Time (h)', family="serif",fontsize = 32)
ax3.set_title('1+2 in LB+Amp+Kan', fontsize = 30, family = 'sarif')
ax3.grid()
ax3.set_ylim(0,40000)


#LB + Amp + Kan + Ara
ax4 = plt.subplot(322)
ax4.plot(x/60, Fluorescence1['E4'], ' ',color='k', marker='o', markersize=18,markerfacecolor="indigo")
ax4.plot(x/60, Fluorescence2['E4'], ' ',color='k', marker='o', markersize=18,markerfacecolor="orange")
ax4.plot(x/60, Fluorescence2['E6'], ' ',color='k', marker='o', markersize=18,markerfacecolor="mediumspringgreen")
ax4.plot(x/60, Fluorescence2['E9'], ' ',color='k', marker='o', markersize=18,markerfacecolor="c")
ax4.plot(x/60, Fluorescence2['E10'], ' ',color='k', marker='o', markersize=18,alpha=0.3, markerfacecolor="indigo")
ax4.set_ylabel(r'Flourescence', family="serif",fontsize = 32)
ax4.set_xlabel(r'Time (h)', family="serif",fontsize = 32)
ax4.set_title('1+2 in LB+Amp+Kan+Ara', fontsize = 30, family = 'sarif')
ax4.grid()
ax1.set_ylim(0,40000)
# Out:
# (0.0, 40000.0)

# %%
#Figure
fig = plt.figure(figsize=(10.5,6))
plt.rc('xtick', labelsize=19)    # fontsize of the tick labels
plt.rc('ytick', labelsize=19)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"
#2+3 LB GFP
x= np.arange(9, len(GFP1)*10,10)
plt.plot(x/60, GFP1['B5'], ' ',color='k', marker='o', markersize=13,markerfacecolor="lime", label = "GFP 2+3")
#plt.plot(x/60, GFP1['B7'], ' ',color='k', marker='o', markersize=15,markerfacecolor="g", label = "GFP 2+3 Plate2")

#1+2 LB GFP
x= np.arange(8, len(GFP1)*10,10)
plt.plot(x/60, GFP1['C4'], ' ',color='k', marker='s', markersize=13,markerfacecolor="lime", label = "GFP 1+2")
#plt.plot(x/60, GFP2['C9'], ' ',color='k', marker='s', markersize=15,markerfacecolor="g", label = "GFP 1+2 Plate2")

#2+3 LB mkate
x= np.arange(9, len(GFP1)*10,10)
#plt.plot(x/60, mkate1['B5'], ' ',color='k', marker='o', markersize=15,markerfacecolor="r", label = "mkate 2+3 Plate1")
plt.plot(x/60, mkate1['B2'], ' ',color='k', marker='o', markersize=13,alpha=0.4,markerfacecolor="r", label = "mkate 2+3 Plate 1")
plt.plot(x/60, mkate2['B2'], ' ',color='k', marker='s', markersize=13,markerfacecolor="r", label = "mkate 2+3 Plate 2")
#1+2 LB mkate
x= np.arange(8, len(GFP1)*10,10)
plt.plot(x/60, mkate2['B2'], ' ',color='k', marker='s', markersize=13,alpha=0.4,markerfacecolor="r", label = "mkate 1+2 Plate 1")
plt.plot(x/60, mkate2['B10'], ' ',color='k', marker='s', markersize=13,markerfacecolor="r", label = "mkate 1+2 Plate 2")

plt.ticklabel_format(axis="y", style="sci", scilimits=(3,3))
plt.xticks(np.arange(0.0, 20, 2.5))
plt.ylabel(r'Fluorescence', family="serif",fontsize = 22)
plt.xlabel(r'Time (h)', family="serif",fontsize = 22)
#plt.title('', fontsize = 30, family = 'sarif')
plt.legend(prop={"size":15, "family": "serif"})
plt.grid()
