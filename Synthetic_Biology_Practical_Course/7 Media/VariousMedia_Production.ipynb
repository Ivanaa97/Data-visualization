# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fast')
data = pd.read_csv('/content/drive/MyDrive/Master/SyntheticBiologyPracticalCourse/VariousMedia_Production/data_VariousMedia_CarotenoidsProduction.csv')
lycopene = data[['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3', 'J1', 'J2', 'J3', 'K1', 'K2', 'K3', 'L1', 'L2', 'L3']]/max(data[['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3', 'J1', 'J2', 'J3', 'K1', 'K2', 'K3', 'L1', 'L2', 'L3']].iloc[:,1:].max().tolist())
lycopene['WL (nm)'] =  data[['WL (nm)']]
BetaCarotene =data[['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6', 'J4', 'J5', 'J6', 'K4', 'K5', 'K6', 'L4', 'L5', 'L6']]/max(data[['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6', 'J4', 'J5', 'J6', 'K4', 'K5', 'K6', 'L4', 'L5', 'L6']].iloc[:,1:].max().tolist())
BetaCarotene['WL (nm)'] = data[['WL (nm)']]
images_dir = '/content/drive/MyDrive/Master/SyntheticBiologyPracticalCourse/VariousMedia_Production'

# %% [markdown]
# # **Lycopene**

# %% [markdown]
# # **$\beta$-Carotene**

# %% [markdown]
# # **Join images**

# %%
plt.rc('xtick', labelsize=25)    # fontsize of the tick labels
plt.rc('ytick', labelsize=25)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"

fig = plt.figure(figsize=(35,30))
#
ax1 = plt.subplot(321)
ax1.plot(lycopene['WL (nm)'], lycopene['G1']/2.89, ' ',color='k', marker='o', markersize=12,markerfacecolor="limegreen",markevery=2, label = "LB Luria/Miller")
print(r"lycopene Max Absorbance G1: " + str(max(lycopene['G1']/2.89)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['G1']/2.89 == max(lycopene['G1']/2.89)].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['H1']/5.07, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkslateblue",markevery=2, label = "LB Lemax")
print(r"lycopene Max Absorbance H1: " + str(max(lycopene['H1']/5.07)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['H1']/5.07 == max(lycopene['H1']/5.07)].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['I1']/3.18, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "TY")
print(r"lycopene Max Absorbance I1: " + str(max(lycopene['I1']/3.18)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['I1']/3.18 == max(lycopene['I1']/3.18)].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['J1']/4.73, ' ',color='k', marker='o', markersize=12,markerfacecolor="yellow",markevery=2, label = "TS")
print(r"lycopene Max Absorbance J1: " + str(max(lycopene['J1']/4.73)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['J1'] == max(lycopene['J1'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['K1']/4.10, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkorange",markevery=2, label = "TB")
print(r"lycopene Max Absorbance K1: " + str(max(lycopene['K1']/4.10)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['K1'] == max(lycopene['K1'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['L1']/4.06, ' ',color='k', marker='o', markersize=12,markerfacecolor="m",markevery=2, label = "Mix1")
print(r"lycopene Max Absorbance L1: " + str(max(lycopene['L1']/4.06)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['L1'] == max(lycopene['L1'])].tolist()[0] + 400))

ax1.set_ylim(0, 0.4)
ax1.set_xlim(400,540)
ax1.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax1.text(380,0.4, '(a)', family = "serif", fontsize= 50)
ax1.axvline(473,  ymin=0,  ymax= 0.55, color='k')
ax1.text(472, 0.23,r'$\lambda_{max}=$473$nm$', family="serif", fontsize=27)
ax1.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax1.set_title(r'Lycopene 0$m$M Ara 0$m$M IPTG', fontsize =40, family = 'serif')
ax1.legend(prop={"size":26, "family": "serif"},loc="upper left")
ax1.grid()
#
ax2 = plt.subplot(322)
ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['G4']/3.19, ' ',color='k', marker='o', markersize=12,markerfacecolor="limegreen",markevery=2, label = "LB Luria/Miller")
print(r"BetaCarotene Max Absorbance G4: " + str(max(BetaCarotene['G4']/3.19)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['G4'] == max(BetaCarotene['G4'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['H4']/3.48, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkslateblue",markevery=2, label = "LB Lemax")
print(r"BetaCarotene Max Absorbance H4: " + str(max(BetaCarotene['H4']/3.48)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['H4'] == max(BetaCarotene['H4'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['I4']/3.1, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "TY")
print(r"BetaCarotene Max Absorbance I4: " + str(max(BetaCarotene['I4']/3.1)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['I4'] == max(BetaCarotene['I4'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['J4']/5.66, ' ',color='k', marker='o', markersize=12,markerfacecolor="yellow",markevery=2, label = "TS")
print(r"BetaCarotene Max Absorbance J4: " + str(max(BetaCarotene['J4']/5.66)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['J4'] == max(BetaCarotene['J4'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['K4']/3.87, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkorange",markevery=2, label = "TB")
print(r"BetaCarotene Max Absorbance K4: " + str(max(BetaCarotene['K4']/3.87)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['K4'] == max(BetaCarotene['K4'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['L4']/2.91, ' ',color='k', marker='o', markersize=12,markerfacecolor="m",markevery=2, label = "Mix1")
print(r"BetaCarotene Max Absorbance L4: " + str(max(BetaCarotene['L4']/2.91)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['L4'] == max(BetaCarotene['L4'])].tolist()[0] + 400))

ax2.set_ylim(0, 0.4)
ax2.set_xlim(400, 540)
ax2.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax2.text(380,0.4, '(b)', family = "serif", fontsize= 50)
ax2.axvline(454,  ymin=0,  ymax= 0.64, color='k')
ax2.text(453, 0.27,r'$\lambda_{max}=$454$nm$', family="serif", fontsize=27)
ax2.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax2.set_title(r'$\beta$-Carotene 0$m$M Ara 0$m$M IPTG', fontsize = 40, family = 'serif')
ax2.legend(prop={"size":26, "family": "serif"})
ax2.grid()

plt.savefig(f"{images_dir}/0Ara0IPTG.png", bbox_inches="tight", dpi=100)
# Out:
# lycopene Max Absorbance G1: 0.08758173021493292 Max $\lambda_{nm}$: 473
# lycopene Max Absorbance H1: 0.05851439937225688 Max $\lambda_{nm}$: 473
# lycopene Max Absorbance I1: 0.06712845489043576 Max $\lambda_{nm}$: 472
# lycopene Max Absorbance J1: 0.2114164904862579 Max $\lambda_{nm}$: 472
# lycopene Max Absorbance K1: 0.04763490027513684 Max $\lambda_{nm}$: 400
# lycopene Max Absorbance L1: 0.03500285757792091 Max $\lambda_{nm}$: 400
# BetaCarotene Max Absorbance G4: 0.2523792540311227 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance H4: 0.22248606235804255 Max $\lambda_{nm}$: 453
# BetaCarotene Max Absorbance I4: 0.2005022213637242 Max $\lambda_{nm}$: 453
# BetaCarotene Max Absorbance J4: 0.17667844522968199 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance K4: 0.17445728697643476 Max $\lambda_{nm}$: 400
# BetaCarotene Max Absorbance L4: 0.06595057308064285 Max $\lambda_{nm}$: 400

# %%
plt.rc('xtick', labelsize=25)    # fontsize of the tick labels
plt.rc('ytick', labelsize=25)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"
fig = plt.figure(figsize=(35,30))
#
ax1 = plt.subplot(321)
ax1.plot(lycopene['WL (nm)'], lycopene['G2']*9/3.21, ' ',color='k', marker='o', markersize=12,markerfacecolor="limegreen",markevery=2, label = "LB Luria/Miller")
print(r"lycopene Max Absorbance G2: " + str(max(lycopene['G2']*9/3.21)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['G2'] == max(lycopene['G2'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['H2']*9/4.26, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkslateblue",markevery=2, label = "LB Lemax")
print(r"lycopene Max Absorbance H2: " + str(max(lycopene['H2']*9/4.26)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['H2'] == max(lycopene['H2'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['I2']*9/3.28, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "TY")
print(r"lycopene Max Absorbance I2: " + str(max(lycopene['I2']*9/3.28)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['I2'] == max(lycopene['I2'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['J2']*9/4.05, ' ',color='k', marker='o', markersize=12,markerfacecolor="yellow",markevery=2, label = "TS")
print(r"lycopene Max Absorbance J2: " + str(max(lycopene['J2']*9/4.05)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['J2'] == max(lycopene['J2'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['K2']*9/3.69, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkorange",markevery=2, label = "TB")
print(r"lycopene Max Absorbance K2: " + str(max(lycopene['K2']*9/3.69)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['K2'] == max(lycopene['K2'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['L2']*9/4, ' ',color='k', marker='o', markersize=12,markerfacecolor="m",markevery=2, label = "Mix1")
print(r"lycopene Max Absorbance L2: " + str(max(lycopene['L2']*9/4)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['L2'] == max(lycopene['L2'])].tolist()[0] + 400))

ax1.set_ylim(0, 1.5)
ax1.set_xlim(400, 540)
ax1.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax1.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax1.set_title(r'Lycopene  1.5$m$M Ara, 100$\mu$M IPTG', fontsize = 40, family = 'serif')
ax1.text(380,1.5, '(c)', family = "serif", fontsize= 50)
ax1.axvline(474,  ymin=0,  ymax= 0.50, color='k')
ax1.text(473, 0.806,r'$\lambda_{max}=$474$nm$', family="serif", fontsize=27)
ax1.legend(prop={"size":25, "family": "serif"}, loc= 'upper left')
ax1.grid()
#
ax2 = plt.subplot(322)
ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['G5']*9/3.45, ' ',color='k', marker='o', markersize=12,markerfacecolor="limegreen",markevery=2,label = "LB Luria/Miller")
print(r"BetaCarotene Max Absorbance G5: " + str(max(BetaCarotene['G5']*9/3.45)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['G5'] == max(BetaCarotene['G5'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['H5']*9/3.81, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkslateblue",markevery=2,label = "LB Lemax")
print(r"BetaCarotene Max Absorbance H5: " + str(max(BetaCarotene['H5']*9/3.81)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['H5'] == max(BetaCarotene['H5'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['I5']*9/3.35, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2,label = "TS")
print(r"BetaCarotene Max Absorbance I5: " + str(max(BetaCarotene['I5']*9/3.35)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['I5'] == max(BetaCarotene['I5'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['J5']*9/3.85, ' ',color='k', marker='o', markersize=12,markerfacecolor="yellow",markevery=2,label = "TB")
print(r"BetaCarotene Max Absorbance J5: " + str(max(BetaCarotene['J5']*9/3.85)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['J5'] == max(BetaCarotene['J5'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['K5']*9/4.78, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkorange",markevery=2,label = "C5")
print(r"BetaCarotene Max Absorbance K5: " + str(max(BetaCarotene['K5']*9/4.78)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['K5'] == max(BetaCarotene['K5'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['L5']*9/3.74, ' ',color='k', marker='o', markersize=12,markerfacecolor="m",markevery=2, label = "Mix1")
print(r"BetaCarotene Max Absorbance L5: " + str(max(BetaCarotene['L5']*9/3.74)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['L5'] == max(BetaCarotene['L5'])].tolist()[0] + 400))

ax2.set_ylim(0, 2.5)
ax2.set_xlim(400, 540)
ax2.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax2.text(380,2.5, '(d)', family = "serif", fontsize= 50)
ax2.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax2.axvline(454,  ymin=0,  ymax= 0.806, color='k')
ax2.text(453, 2.1,r'$\lambda_{max}=$454$nm$', family="serif", fontsize=27)
ax2.set_title(r'$\beta$-Carotene  1.5$m$M Ara, 100$\mu$M IPTG', fontsize = 40, family = 'serif')
ax2.legend(prop={"size":26, "family": "serif"})
ax2.grid()

plt.savefig(f"{images_dir}/1_5Ara100microIPTG.png", bbox_inches="tight", dpi=100)
# Out:
# lycopene Max Absorbance G2: 0.7459564713341862 Max $\lambda_{nm}$: 474
# lycopene Max Absorbance H2: 0.4806740886911191 Max $\lambda_{nm}$: 474
# lycopene Max Absorbance I2: 0.645219130332612 Max $\lambda_{nm}$: 474
# lycopene Max Absorbance J2: 0.4404745974396718 Max $\lambda_{nm}$: 474
# lycopene Max Absorbance K2: 0.33510883081532544 Max $\lambda_{nm}$: 473
# lycopene Max Absorbance L2: 0.09461561621838618 Max $\lambda_{nm}$: 473
# BetaCarotene Max Absorbance G5: 1.8542046342098415 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance H5: 1.5481635154887077 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance I5: 1.9706854946822774 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance J5: 0.8937708997589238 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance K5: 0.9814471475459124 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance L5: 0.21326331294629994 Max $\lambda_{nm}$: 452

# %%
plt.rc('xtick', labelsize=25)    # fontsize of the tick labels
plt.rc('ytick', labelsize=25)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"
fig = plt.figure(figsize=(35,30))
#
ax1 = plt.subplot(321)
ax1.plot(lycopene['WL (nm)'], lycopene['G3']*9/2.9, ' ',color='k', marker='o', markersize=12,markerfacecolor="limegreen", markevery=2,label = "LB Luria/Miller")
print(r"lycopene Max Absorbance G3: " + str(max(lycopene['G3']*9/2.9)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['G3'] == max(lycopene['G3'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['H3']*9/2.45, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkslateblue",markevery=2,label = "LB Lemax")
print(r"lycopene Max Absorbance H3: " + str(max(lycopene['H3']*9/2.45)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['H3'] == max(lycopene['H3'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['I3']*9/2.35, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2,label = "TY")
print(r"lycopene Max Absorbance I3: " + str(max(lycopene['I3']*9/2.35)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['I3'] == max(lycopene['I3'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['J3']*9/4.16, ' ',color='k', marker='o', markersize=12,markerfacecolor="yellow",markevery=2,label = "TS")
print(r"lycopene Max Absorbance J3: " + str(max(lycopene['J3']*9/4.16)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['J3'] == max(lycopene['J3'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['K3']*9/3.85, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkorange",markevery=2,label = "TB")
print(r"lycopene Max Absorbance K3: " + str(max(lycopene['K3']*9/3.85)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['K3'] == max(lycopene['K3'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['L3']*9/4.87, ' ',color='k', marker='o', markersize=12,markerfacecolor="m",markevery=2, label = "Mix1")
print(r"lycopene Max Absorbance L3: " + str(max(lycopene['L3']*9/4.87)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['L3'] == max(lycopene['L3'])].tolist()[0] + 400))
ax1.set_ylim(0, 1.5)
ax1.set_xlim(400, 540)
ax1.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax1.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax1.text(380,1.5, '(e)', family = "serif", fontsize= 50)
ax1.set_title(r'Lycopene  15$m$M Ara, 1$m$M IPTG', fontsize = 40, family = 'serif')
ax1.axvline(474,  ymin=0,  ymax= 0.67, color='k')
ax1.text(473, 1.05,r'$\lambda_{max}=$474$nm$', family="serif", fontsize=27)
ax1.legend(prop={"size":26, "family": "serif"}, loc = 'upper left')
ax1.grid()

ax2 = plt.subplot(322)
ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['G6']*9/2.72, ' ',color='k', marker='o', markersize=12,markerfacecolor="limegreen", markevery=2,label = "LB Luria/Miller")
print(r"BetaCarotene Max Absorbance G6: " + str(max(BetaCarotene['G6']*9/2.72)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['G6'] == max(BetaCarotene['G6'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['H6']*9/2.92, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkslateblue",markevery=2, label = "LB Lemax")
print(r"BetaCarotene Max Absorbance H6: " + str(max(BetaCarotene['H6']*9/2.92)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['H6'] == max(BetaCarotene['H6'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['I6']*9/2.45, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "TY")
print(r"BetaCarotene Max Absorbance I6: " + str(max(BetaCarotene['I6']*9/2.45)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['I6'] == max(BetaCarotene['I6'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['J6']*9/4.24, ' ',color='k', marker='o', markersize=12,markerfacecolor="yellow",markevery=2, label = "TS")
print(r"BetaCarotene Max Absorbance J6: " + str(max(BetaCarotene['J6']*9/4.24)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['J6'] == max(BetaCarotene['J6'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['K6']*4.5/3.19, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkorange",markevery=2, label = "TB")
print(r"BetaCarotene Max Absorbance K6: " + str(max(BetaCarotene['K6']*4.5/3.19)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['K6'] == max(BetaCarotene['K6'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['L6']*9/4.58, ' ',color='k', marker='o', markersize=12,markerfacecolor="m",markevery=2, label = "Mix1")
print(r"BetaCarotene Max Absorbance L6: " + str(max(BetaCarotene['L6']*9/4.58)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['L6'] == max(BetaCarotene['L6'])].tolist()[0] + 400))

ax2.set_ylim(0, 2.5)
ax2.set_xlim(400, 540)
ax2.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax2.text(380,2.5, '(f)', family = "serif", fontsize= 50)
ax2.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax2.axvline(455,  ymin=0,  ymax= 0.73, color='k')
ax2.text(454, 1.9,r'$\lambda_{max}=$455$nm$', family="serif", fontsize=27)
ax2.set_title(r'$\beta$-Carotene  15$m$M Ara, 1$m$M IPTG', fontsize = 40, family = 'serif')
ax2.legend(prop={"size":26, "family": "serif"})
ax2.grid()

plt.savefig(f"{images_dir}/15Ara100IPTG.png", bbox_inches="tight", dpi=100)
# Out:
# lycopene Max Absorbance G3: 0.7855175182380708 Max $\lambda_{nm}$: 474
# lycopene Max Absorbance H3: 0.7469338598546604 Max $\lambda_{nm}$: 474
# lycopene Max Absorbance I3: 0.5450259231104316 Max $\lambda_{nm}$: 474
# lycopene Max Absorbance J3: 0.35022716394404474 Max $\lambda_{nm}$: 474
# lycopene Max Absorbance K3: 0.9879462167699824 Max $\lambda_{nm}$: 474
# lycopene Max Absorbance L3: 0.22145431973997565 Max $\lambda_{nm}$: 474
# BetaCarotene Max Absorbance G6: 1.752487671715393 Max $\lambda_{nm}$: 455
# BetaCarotene Max Absorbance H6: 1.7745673037486671 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance I6: 1.4363925210802884 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance J6: 0.8490566037735849 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance K6: 0.4282657256020874 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance L6: 0.37242109667128626 Max $\lambda_{nm}$: 453

# %% [markdown]
# # **Separadas**

# %%
plt.rc('xtick', labelsize=25)    # fontsize of the tick labels
plt.rc('ytick', labelsize=25)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"

fig = plt.figure(figsize=(35,30))
#
ax1 = plt.subplot(321)
ax1.plot(lycopene['WL (nm)'], lycopene['G1']/2.89, ' ',color='k', marker='o', markersize=12,markerfacecolor="limegreen",markevery=2, label = "LB Luria/Miller")
print(r"lycopene Max Absorbance G1: " + str(max(lycopene['G1']/2.89)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['G1']/2.89 == max(lycopene['G1']/2.89)].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['H1']/5.07, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkslateblue",markevery=2, label = "LB Lemax")
print(r"lycopene Max Absorbance H1: " + str(max(lycopene['H1']/5.07)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['H1']/5.07 == max(lycopene['H1']/5.07)].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['I1']/3.18, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "TY")
print(r"lycopene Max Absorbance I1: " + str(max(lycopene['I1']/3.18)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['I1']/3.18 == max(lycopene['I1']/3.18)].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['J1']/4.73, ' ',color='k', marker='o', markersize=12,markerfacecolor="yellow",markevery=2, label = "TS")
print(r"lycopene Max Absorbance J1: " + str(max(lycopene['J1']/4.73)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['J1'] == max(lycopene['J1'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['K1']/4.10, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkorange",markevery=2, label = "TB")
print(r"lycopene Max Absorbance K1: " + str(max(lycopene['K1']/4.10)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['K1'] == max(lycopene['K1'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['L1']/4.06, ' ',color='k', marker='o', markersize=12,markerfacecolor="m",markevery=2, label = "Mix1")
print(r"lycopene Max Absorbance L1: " + str(max(lycopene['L1']/4.06)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['L1'] == max(lycopene['L1'])].tolist()[0] + 400))

ax1.set_ylim(0, 0.4)
ax1.set_xlim(400,540)
ax1.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax1.text(380,0.4, '(a)', family = "serif", fontsize= 50)
ax1.axvline(473,  ymin=0,  ymax= 0.55, color='k')
ax1.text(472, 0.23,r'$\lambda_{max}=$473$nm$', family="serif", fontsize=27)
ax1.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax1.set_title(r'Lycopene 0$m$M Ara 0$m$M IPTG', fontsize =40, family = 'serif')
ax1.legend(prop={"size":26, "family": "serif"},loc="upper left")
ax1.grid()
plt.savefig(f"{images_dir}/1Lycopene.png", bbox_inches="tight", dpi=100)
#

fig = plt.figure(figsize=(35,30))
#
ax1 = plt.subplot(321)
ax1.plot(lycopene['WL (nm)'], lycopene['G2']*9/3.21, ' ',color='k', marker='o', markersize=12,markerfacecolor="limegreen",markevery=2, label = "LB Luria/Miller")
print(r"lycopene Max Absorbance G2: " + str(max(lycopene['G2']*10/3.21)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['G2'] == max(lycopene['G2'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['H2']*9/4.26, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkslateblue",markevery=2, label = "LB Lemax")
print(r"lycopene Max Absorbance H2: " + str(max(lycopene['H2']*10/4.26)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['H2'] == max(lycopene['H2'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['I2']*9/3.28, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "TY")
print(r"lycopene Max Absorbance I2: " + str(max(lycopene['I2']*10/3.28)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['I2'] == max(lycopene['I2'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['J2']*9/4.05, ' ',color='k', marker='o', markersize=12,markerfacecolor="yellow",markevery=2, label = "TS")
print(r"lycopene Max Absorbance J2: " + str(max(lycopene['J2']*10/4.05)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['J2'] == max(lycopene['J2'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['K2']*9/3.69, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkorange",markevery=2, label = "TB")
print(r"lycopene Max Absorbance K2: " + str(max(lycopene['K2']*10/3.69)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['K2'] == max(lycopene['K2'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['L2']*9/4, ' ',color='k', marker='o', markersize=12,markerfacecolor="m",markevery=2, label = "Mix1")
print(r"lycopene Max Absorbance L2: " + str(max(lycopene['L2']*10/4)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['L2'] == max(lycopene['L2'])].tolist()[0] + 400))

ax1.set_ylim(0, 1.5)
ax1.set_xlim(400, 540)
ax1.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax1.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax1.set_title(r'Lycopene  1.5$m$M Ara, 100$\mu$M IPTG', fontsize = 40, family = 'serif')
ax1.text(380,1.5, '(b)', family = "serif", fontsize= 50)
ax1.axvline(474,  ymin=0,  ymax= 0.50, color='k')
ax1.text(473, 0.806,r'$\lambda_{max}=$474$nm$', family="serif", fontsize=27)
ax1.legend(prop={"size":26, "family": "serif"}, loc= 'upper left')
ax1.grid()
plt.savefig(f"{images_dir}/2Lycopene.png", bbox_inches="tight", dpi=100)
#

fig = plt.figure(figsize=(35,30))

ax1 = plt.subplot(321)
ax1.plot(lycopene['WL (nm)'], lycopene['G3']*9/2.9, ' ',color='k', marker='o', markersize=12,markerfacecolor="limegreen", markevery=2,label = "LB Luria/Miller")
print(r"lycopene Max Absorbance G3: " + str(max(lycopene['G3']*10/2.9)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['G3'] == max(lycopene['G3'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['H3']*9/2.45, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkslateblue",markevery=2,label = "LB Lemax")
print(r"lycopene Max Absorbance H3: " + str(max(lycopene['H3']*10/2.45)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['H3'] == max(lycopene['H3'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['I3']*9/2.35, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2,label = "TY")
print(r"lycopene Max Absorbance I3: " + str(max(lycopene['I3']*10/2.35)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['I3'] == max(lycopene['I3'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['J3']*9/4.16, ' ',color='k', marker='o', markersize=12,markerfacecolor="yellow",markevery=2,label = "TS")
print(r"lycopene Max Absorbance J3: " + str(max(lycopene['J3']*10/4.16)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['J3'] == max(lycopene['J3'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['K3']*9/3.85, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkorange",markevery=2,label = "TB")
print(r"lycopene Max Absorbance K3: " + str(max(lycopene['K3']*10/3.85)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['K3'] == max(lycopene['K3'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['L3']*9/4.87, ' ',color='k', marker='o', markersize=12,markerfacecolor="m",markevery=2, label = "Mix1")
print(r"lycopene Max Absorbance L3: " + str(max(lycopene['L3']*10/4.87)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['L3'] == max(lycopene['L3'])].tolist()[0] + 400))
ax1.set_ylim(0, 1.5)
ax1.set_xlim(400, 540)
ax1.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax1.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax1.text(380,1.5, '(c)', family = "serif", fontsize= 50)
ax1.set_title(r'Lycopene  15$m$M Ara, 1$m$M IPTG', fontsize = 40, family = 'serif')
ax1.axvline(474,  ymin=0,  ymax= 0.67, color='k')
ax1.text(473, 1.05,r'$\lambda_{max}=$474$nm$', family="serif", fontsize=27)
ax1.legend(prop={"size":26, "family": "serif"}, loc = 'upper left')
ax1.grid()
plt.savefig(f"{images_dir}/3Lycopene.png", bbox_inches="tight", dpi=100)
# Out:
# lycopene Max Absorbance G1: 0.08758173021493292 Max $\lambda_{nm}$: 473
# lycopene Max Absorbance H1: 0.05851439937225688 Max $\lambda_{nm}$: 473
# lycopene Max Absorbance I1: 0.06712845489043576 Max $\lambda_{nm}$: 472
# lycopene Max Absorbance J1: 0.2114164904862579 Max $\lambda_{nm}$: 472
# lycopene Max Absorbance K1: 0.04763490027513684 Max $\lambda_{nm}$: 400
# lycopene Max Absorbance L1: 0.03500285757792091 Max $\lambda_{nm}$: 400
# lycopene Max Absorbance G2: 0.8288405237046514 Max $\lambda_{nm}$: 474
# lycopene Max Absorbance H2: 0.5340823207679101 Max $\lambda_{nm}$: 474
# lycopene Max Absorbance I2: 0.7169101448140134 Max $\lambda_{nm}$: 474
# lycopene Max Absorbance J2: 0.48941621937741314 Max $\lambda_{nm}$: 474
# lycopene Max Absorbance K2: 0.3723431453503616 Max $\lambda_{nm}$: 473
# lycopene Max Absorbance L2: 0.10512846246487353 Max $\lambda_{nm}$: 473
# lycopene Max Absorbance G3: 0.8727972424867454 Max $\lambda_{nm}$: 474
# ...

# %%
fig = plt.figure(figsize=(35,30))
ax2 = plt.subplot(322)
ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['G4']/3.19, ' ',color='k', marker='o', markersize=12,markerfacecolor="limegreen",markevery=2, label = "LB Luria/Miller")
print(r"BetaCarotene Max Absorbance G4: " + str(max(BetaCarotene['G4']/3.19)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['G4'] == max(BetaCarotene['G4'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['H4']/3.48, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkslateblue",markevery=2, label = "LB Lemax")
print(r"BetaCarotene Max Absorbance H4: " + str(max(BetaCarotene['H4']/3.48)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['H4'] == max(BetaCarotene['H4'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['I4']/3.1, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "TY")
print(r"BetaCarotene Max Absorbance I4: " + str(max(BetaCarotene['I4']/3.1)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['I4'] == max(BetaCarotene['I4'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['J4']/5.66, ' ',color='k', marker='o', markersize=12,markerfacecolor="yellow",markevery=2, label = "TS")
print(r"BetaCarotene Max Absorbance J4: " + str(max(BetaCarotene['J4']/5.66)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['J4'] == max(BetaCarotene['J4'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['K4']/3.87, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkorange",markevery=2, label = "TB")
print(r"BetaCarotene Max Absorbance K4: " + str(max(BetaCarotene['K4']/3.87)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['K4'] == max(BetaCarotene['K4'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['L4']/2.91, ' ',color='k', marker='o', markersize=12,markerfacecolor="m",markevery=2, label = "Mix1")
print(r"BetaCarotene Max Absorbance L4: " + str(max(BetaCarotene['L4']/2.91)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['L4'] == max(BetaCarotene['L4'])].tolist()[0] + 400))

ax2.set_ylim(0, 0.4)
ax2.set_xlim(400, 540)
ax2.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax2.text(380,0.4, '(d)', family = "serif", fontsize= 50)
ax2.axvline(454,  ymin=0,  ymax= 0.64, color='k')
ax2.text(453, 0.27,r'$\lambda_{max}=$454$nm$', family="serif", fontsize=27)
ax2.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax2.set_title(r'$\beta$-Carotene 0$m$M Ara 0$m$M IPTG', fontsize = 40, family = 'serif')
ax2.legend(prop={"size":26, "family": "serif"})
ax2.grid()
plt.savefig(f"{images_dir}/1Carotene.png", bbox_inches="tight", dpi=100)
#

fig = plt.figure(figsize=(35,30))

ax2 = plt.subplot(322)
ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['G5']*9/3.45, ' ',color='k', marker='o', markersize=12,markerfacecolor="limegreen",markevery=2,label = "LB Luria/Miller")
print(r"BetaCarotene Max Absorbance G5: " + str(max(BetaCarotene['G5']*10/3.45)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['G5'] == max(BetaCarotene['G5'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['H5']*9/3.81, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkslateblue",markevery=2,label = "LB Lemax")
print(r"BetaCarotene Max Absorbance H5: " + str(max(BetaCarotene['H5']*10/3.81)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['H5'] == max(BetaCarotene['H5'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['I5']*9/3.35, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2,label = "TS")
print(r"BetaCarotene Max Absorbance I5: " + str(max(BetaCarotene['I5']*10/3.35)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['I5'] == max(BetaCarotene['I5'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['J5']*9/3.85, ' ',color='k', marker='o', markersize=12,markerfacecolor="yellow",markevery=2,label = "TB")
print(r"BetaCarotene Max Absorbance J5: " + str(max(BetaCarotene['J5']*10/3.85)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['J5'] == max(BetaCarotene['J5'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['K5']*9/4.78, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkorange",markevery=2,label = "C5")
print(r"BetaCarotene Max Absorbance K5: " + str(max(BetaCarotene['K5']*10/4.78)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['K5'] == max(BetaCarotene['K5'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['L5']*9/3.74, ' ',color='k', marker='o', markersize=12,markerfacecolor="m",markevery=2, label = "Mix1")
print(r"BetaCarotene Max Absorbance L5: " + str(max(BetaCarotene['L5']*10/3.74)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['L5'] == max(BetaCarotene['L5'])].tolist()[0] + 400))

ax2.set_ylim(0, 2.5)
ax2.set_xlim(400, 540)
ax2.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax2.text(380,2.5, '(e)', family = "serif", fontsize= 50)
ax2.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax2.axvline(454,  ymin=0,  ymax= 0.806, color='k')
ax2.text(453, 2.1,r'$\lambda_{max}=$454$nm$', family="serif", fontsize=27)
ax2.set_title(r'$\beta$-Carotene  1.5$m$M Ara, 100$\mu$M IPTG', fontsize = 40, family = 'serif')
ax2.legend(prop={"size":26, "family": "serif"})
ax2.grid()
plt.savefig(f"{images_dir}/2Carotene.png", bbox_inches="tight", dpi=100)

#

fig = plt.figure(figsize=(35,30))
ax2 = plt.subplot(322)
ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['G6']*9/2.72, ' ',color='k', marker='o', markersize=12,markerfacecolor="limegreen", markevery=2,label = "LB Luria/Miller")
print(r"BetaCarotene Max Absorbance G6: " + str(max(BetaCarotene['G6']*10/2.72)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['G6'] == max(BetaCarotene['G6'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['H6']*9/2.92, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkslateblue",markevery=2, label = "LB Lemax")
print(r"BetaCarotene Max Absorbance H6: " + str(max(BetaCarotene['H6']*10/2.92)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['H6'] == max(BetaCarotene['H6'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['I6']*9/2.45, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "TY")
print(r"BetaCarotene Max Absorbance I6: " + str(max(BetaCarotene['I6']*10/2.45)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['I6'] == max(BetaCarotene['I6'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['J6']*9/4.24, ' ',color='k', marker='o', markersize=12,markerfacecolor="yellow",markevery=2, label = "TS")
print(r"BetaCarotene Max Absorbance J6: " + str(max(BetaCarotene['J6']*10/4.24)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['J6'] == max(BetaCarotene['J6'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['K6']*4.5/3.19, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkorange",markevery=2, label = "TB")
print(r"BetaCarotene Max Absorbance K6: " + str(max(BetaCarotene['K6']*5/3.19)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['K6'] == max(BetaCarotene['K6'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['L6']*9/4.58, ' ',color='k', marker='o', markersize=12,markerfacecolor="m",markevery=2, label = "Mix1")
print(r"BetaCarotene Max Absorbance L6: " + str(max(BetaCarotene['L6']*10/4.58)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['L6'] == max(BetaCarotene['L6'])].tolist()[0] + 400))

ax2.set_ylim(0, 2.5)
ax2.set_xlim(400, 540)
ax2.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax2.text(380,2.5, '(f)', family = "serif", fontsize= 50)
ax2.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax2.axvline(455,  ymin=0,  ymax= 0.73, color='k')
ax2.text(454, 1.9,r'$\lambda_{max}=$455$nm$', family="serif", fontsize=27)
ax2.set_title(r'$\beta$-Carotene  15$m$M Ara, 1$m$M IPTG', fontsize = 40, family = 'serif')
ax2.legend(prop={"size":26, "family": "serif"})
ax2.grid()

plt.savefig(f"{images_dir}/3Carotene.png", bbox_inches="tight", dpi=100)
# Out:
# BetaCarotene Max Absorbance G4: 0.2523792540311227 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance H4: 0.22248606235804255 Max $\lambda_{nm}$: 453
# BetaCarotene Max Absorbance I4: 0.2005022213637242 Max $\lambda_{nm}$: 453
# BetaCarotene Max Absorbance J4: 0.17667844522968199 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance K4: 0.17445728697643476 Max $\lambda_{nm}$: 400
# BetaCarotene Max Absorbance L4: 0.06595057308064285 Max $\lambda_{nm}$: 400
# BetaCarotene Max Absorbance G5: 2.0602273713442685 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance H5: 1.720181683876342 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance I5: 2.189650549646975 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance J5: 0.9930787775099154 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance K5: 1.0904968306065692 Max $\lambda_{nm}$: 454
# BetaCarotene Max Absorbance L5: 0.2369592366069999 Max $\lambda_{nm}$: 452
# ...
