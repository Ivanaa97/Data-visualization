# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fast')
data = pd.read_csv('/content/drive/MyDrive/Master/SyntheticBiologyPracticalCourse/VariousMedia_Production/data_VariousMedia_CarotenoidsProduction.csv')
lycopene = data[['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3', 'J1', 'J2', 'J3', 'K1', 'K2', 'K3', 'L1', 'L2', 'L3']]/max(data[['G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3', 'J1', 'J2', 'J3', 'K1', 'K2', 'K3', 'L1', 'L2', 'L3']].iloc[:,1:].max().tolist())
lycopene['WL (nm)'] =  data[['WL (nm)']]
BetaCarotene =data[['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6', 'J4', 'J5', 'J6', 'K4', 'K5', 'K6', 'L4', 'L5', 'L6']]/max(data[['G4', 'G5', 'G6', 'H4', 'H5', 'H6', 'I4', 'I5', 'I6', 'J4', 'J5', 'J6', 'K4', 'K5', 'K6', 'L4', 'L5', 'L6']].iloc[:,1:].max().tolist())
BetaCarotene['WL (nm)'] = data[['WL (nm)']]
images_dir = '/content/drive/MyDrive/Master/SyntheticBiologyPracticalCourse/VariousMedia_Production'

# %% [markdown]
# # **Lycopene**

# %%
plt.rc('xtick', labelsize=25)    # fontsize of the tick labels
plt.rc('ytick', labelsize=25)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"


# set width of bar
barWidth = 0.25
fig = plt.figure(figsize=(20,11))

# set height of bar
lycopene_0Ara_0IPTG = [0.08758173021493292*1000000*(10/9)/(150479),0.05851439937225688*1000000*(10/9)/(150479),0.06712845489043576*1000000*(10/9)/(150479), 0.2114164904862579*1000000*(10/9)/(150479),0.04763490027513684*1000000*(10/9)/(150479),0.03500285757792091*1000000*(10/9)/(150479)]
lycopene_1p5Ara_100IPTG  = [0.7459564713341862*1000000*(10/9)/(150479),  0.4806740886911191*1000000*(10/9)/(150479),0.645219130332612*1000000*(10/9)/(150479),0.4404745974396718*1000000*(10/9)/(150479), 0.09461561621838618*1000000*(10/9)/(150479), 0.09461561621838618*1000000*(10/9)/(150479)]
lycopene_15Ara_1IPTG = [0.7855175182380708*1000000*(10/9)/(150479),  0.7469338598546604*1000000*(10/9)/(150479), 0.5450259231104316*1000000*(10/9)/(150479), 0.35022716394404474*1000000*(10/9)/(150479), 0.9879462167699824*1000000*(10/9)/(150479), 0.22145431973997565*1000000*(10/9)/(150479)]

labels =["LB-Agar Luria/Miller","LB Lemax","TY","TS", "TB", "Mix1","Mix2"]

# Set position of bar on X axis
br1 = np.arange(len(lycopene_0Ara_0IPTG))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

# Make the plot

plt.bar(br1, lycopene_0Ara_0IPTG, color='mistyrose', width= barWidth, edgecolor= 'k', label='0M Ara, 0M IPTG')
plt.bar(br2, lycopene_1p5Ara_100IPTG, color='k', width= barWidth, edgecolor= 'k', label=r'1.5mM Ara, 100$\mu$M IPTG')
plt.bar(br3, lycopene_15Ara_1IPTG, color='crimson', width= barWidth, edgecolor= 'k', label='15mM Ara, 1mM IPTG')
plt.ylabel('Lycopene ($\mu$M)', family = 'serif',fontsize = 35)
plt.xlabel('Media', family = 'serif',fontsize = 35)

plt.xticks([r + barWidth for r in range(len(lycopene_0Ara_0IPTG))], ["LB Luria/Miller","LB Lemax","TY","TS", "TB", "Mix1","Mix2"], rotation=25)
plt.text(-0.8, 0.9879462167699824*1000000*(10/9)/(150479), '(a)', fontsize = 40, family = 'serif')
plt.title(r'Lycopene production', family = 'serif',fontsize = 40)
plt.legend(prop={'size':25})
plt.savefig(f"{images_dir}/BarLycopene.png", bbox_inches="tight", dpi=100)

# %%
 0.9879462167699824*1000000*(10/9)/(150479)
# Out:
# 7.294825315381639

# %% [markdown]
# # **$\beta$-Carotene**

# %%
plt.rc('xtick', labelsize=25)    # fontsize of the tick labels
plt.rc('ytick', labelsize=25)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"


# set width of bar
barWidth = 0.25
fig = plt.figure(figsize=(20,11))

# set height of bar
carotene_0Ara_0IPTG = [0.2523792540311227*1000000*(10/9)/(139500),0.22248606235804255*1000000*(10/9)/(139500),0.2005022213637242 *1000000*(10/9)/(139500), 0.17667844522968199*1000000*(10/9)/(139500), 0.17445728697643476*1000000*(10/9)/(139500),0.06595057308064285*1000000*(10/9)/(139500)]
carotene_1p5Ara_100IPTG  = [1.8542046342098415*1000000*(10/9)/(139500), 1.5481635154887077*1000000*(10/9)/(139500), 1.9706854946822774*1000000*(10/9)/(139500),0.8937708997589238*1000000*(10/9)/(139500), 0.9814471475459124*1000000*(10/9)/(139500), 0.21326331294629994*1000000*(10/9)/(139500)]
carotene_15Ara_1IPTG = [1.752487671715393*1000000*(10/9)/(139500),  1.7745673037486671*1000000*(10/9)/(139500), 1.4363925210802884*1000000*(10/9)/(139500), 0.8490566037735849*1000000*(10/9)/(139500), 0.4282657256020874*1000000*(5/4.5)/(139500), 0.37242109667128626*1000000*(10/9)/(139500)]


labels =["LB-Agar Luria/Miller","LB Lemax","TY","TS", "TB", "Mix1","Mix2"]

# Set position of bar on X axis
br1 = np.arange(len(carotene_0Ara_0IPTG))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

# Make the plot

plt.bar(br1, carotene_0Ara_0IPTG, color='lightyellow', width= barWidth, edgecolor= 'k', label='0M Ara, 0M IPTG')
plt.bar(br2, carotene_1p5Ara_100IPTG, color='gray', width= barWidth, edgecolor= 'k', label=r'1.5mM Ara, 100$\mu$M IPTG')
plt.bar(br3, carotene_15Ara_1IPTG, color='darkorange', width= barWidth, edgecolor= 'k', label='15mM Ara, 1mM IPTG')
plt.ylabel(r'$\beta$-Carotene ($\mu$M)', family = 'serif',fontsize = 35)
plt.xlabel('Media', family = 'serif',fontsize = 35)

plt.xticks([r + barWidth for r in range(len(carotene_0Ara_0IPTG))], ["LB Luria/Miller","LB Lemax","TY","TS", "TB", "Mix1","Mix2"], rotation=25)
plt.text(-0.8, 2.02*1000000*(10/9)/(136900), '(b)', fontsize = 40, family = 'serif')
plt.title(r'$\beta$-Carotene production', family = 'serif',fontsize = 40)
plt.legend(prop={'size':25})
plt.savefig(f"{images_dir}/BarCarotene.png", bbox_inches="tight", dpi=100)

# %%
2.02*1000000*(10/9)/(136900)
# Out:
# 16.394773151529908
