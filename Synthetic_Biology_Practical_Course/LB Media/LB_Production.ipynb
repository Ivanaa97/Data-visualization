# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fast')
data = pd.read_csv('/content/drive/MyDrive/Master/SyntheticBiologyPracticalCourse/LB_Production/data_LB_CarotenoidsProduction.csv')

lycopene = data[['WL (nm)','C1Ioana','A12','C2','C3','C5','C6','C8Ioana','C9','C10','C11','C12Ioana','D1Ioana','D2','D3','D5','D6','D8Ioana','D9','D10','D11','D12Ioana']]#/max(data[['C1Ioana','C2','C3','C5','C6','C8Ioana','C9','C10','C11','C12Ioana','D1Ioana','D2','D3','D5','D6','D8Ioana','D9','D10','D11','D12Ioana']].iloc[:,1:].max().tolist())

BetaCarotene = data[['WL (nm)','E1Ioana','A12','E2','E3','E5','E6','E8Ioana','E9','E10','E11','E12Ioana','F1Ioana','F2','F3','F5','F6','F8Ioana','F9','F10','F11','F12Ioanax1','F12Ioanax2']]#/max(data[['E1Ioana','E2','E3','E5','E6','E8Ioana','E9','E10','E11','E12Ioana','F1Ioana','F2','F3','F5','F6','F8Ioana','F9','F10','F11','F12Ioanax1','F12Ioanax2']].iloc[:,1:].max().tolist())


images_dir = '/content/drive/MyDrive/Master/SyntheticBiologyPracticalCourse/LB_Production'
data
# Out:
#      WL (nm)      A1     A12  A1Ioana  ...  F1Ioana  F8Ioana  F12Ioanax1  F12Ioanax2
# 0        400  0.1935  0.1673   0.2442  ...   0.2428   0.3736      0.7676      1.1053
# 1        401  0.1926  0.1666   0.2432  ...   0.2437   0.3795      0.7851      1.1323
# 2        402  0.1915  0.1660   0.2425  ...   0.2443   0.3861      0.8034      1.1589
# 3        403  0.1906  0.1656   0.2420  ...   0.2450   0.3936      0.8205      1.1841
# 4        404  0.1897  0.1651   0.2415  ...   0.2456   0.4019      0.8374      1.2091
# ..       ...     ...     ...      ...  ...      ...      ...         ...         ...
# 142      542  0.1246  0.1192   0.1869  ...   0.1487   0.1435      0.1043      0.2029
# 143      543  0.1244  0.1189   0.1866  ...   0.1483   0.1375      0.1028      0.2012
# 144      544  0.1242  0.1186   0.1862  ...   0.1480   0.1322      0.1013      0.1995
# 145      545  0.1239  0.1183   0.1859  ...   0.1477   0.1274      0.1000      0.1980
# ...

# %%
plt.rc('xtick', labelsize=25)    # fontsize of the tick labels
plt.rc('ytick', labelsize=25)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"

fig = plt.figure(figsize=(35,30))
#
ax1 = plt.subplot(321)
ax1.plot(lycopene['WL (nm)'], lycopene['A12'], ' ',color='k', marker='o', markersize=12,markerfacecolor="k",markevery=2, label = "Negative control 'A'")

ax1.plot(lycopene['WL (nm)'], lycopene['C2']*4.3/4.3, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "0 IPTG")
print(r"Max Absorbance C2: " + str(max(lycopene['C2']*4.3/4.3)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['C2'] == max(lycopene['C2'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['C5']*4.3/4.44, ' ',color='k', marker='o', markersize=12,markerfacecolor="gold",markevery=2, label = r"10$\mu$ IPTG")
print(r"Max Absorbance C5: " + str(max(lycopene['C5']*4.3/4.44)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['C5'] == max(lycopene['C5'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['C8Ioana']*4.3/3.93, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkviolet",markevery=2, label = r"100$\mu$ IPTG")
print(r"Max Absorbance C8: " + str(max(lycopene['C8Ioana']*4.3/3.93)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['C8Ioana'] == max(lycopene['C8Ioana'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['C11']*4.3/3.5, ' ',color='k', marker='o', markersize=12,markerfacecolor="springgreen",markevery=2, label = r"1$m$ IPTG")
print(r"Max Absorbance C11: " + str(max(lycopene['C11']*4.3/3.5)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['C11'] == max(lycopene['C11'])].tolist()[0] + 400))

ax1.set_ylim(0, 2)
ax1.set_xlim(400,540)
ax1.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax1.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax1.text(380, 2, r'(a)', family="serif",fontsize = 50)
ax1.axvline(474,  ymin=0,  ymax= 0.53, color='k')
ax1.text(473, 1.1,r'$\lambda_{max}=$474$nm$', family="serif", fontsize=27)
ax1.set_title(r'"Plasmids C"  Lycopene (1.5$m$M Ara)', fontsize =40, family = 'serif')
ax1.legend(prop={"size":26, "family": "serif"}, loc='upper left')
ax1.grid()
plt.savefig(f"{images_dir}/LycopeneC1_5Ara.png", bbox_inches="tight", dpi=100)

#
fig = plt.figure(figsize=(35,30))
ax2 = plt.subplot(322)

ax2.plot(lycopene['WL (nm)'], lycopene['A12'], ' ',color='k', marker='o', markersize=12,markerfacecolor="k",markevery=2, label = "Negative control 'A'")

ax2.plot(lycopene['WL (nm)'], lycopene['C3']*4.3/3, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "0 IPTG")
print(r"Max Absorbance C3: " + str(max(lycopene['C3']*4.3/3)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['C3'] == max(lycopene['C3'])].tolist()[0] + 400))

ax2.plot(lycopene['WL (nm)'], lycopene['C6']*4.3/3.2, ' ',color='k', marker='o', markersize=12,markerfacecolor="gold",markevery=2, label = r"10$\mu$ IPTG")
print(r"Max Absorbance C6: " + str(max(lycopene['C6']*4.3/3.2)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['C6'] == max(lycopene['C6'])].tolist()[0] + 400))

ax2.plot(lycopene['WL (nm)'], lycopene['C9']*4.3/3.6, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkviolet",markevery=2, label = r"100$\mu$ IPTG")
print(r"Max Absorbance C9: " + str(max(lycopene['C9']*4.3/3.6)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['C9'] == max(lycopene['C9'])].tolist()[0] + 400))

ax2.plot(lycopene['WL (nm)'], lycopene['C12Ioana']*4.3/3.6, ' ',color='k', marker='o', markersize=12,markerfacecolor="springgreen",markevery=2, label = r"1$m$ IPTG")
print(r"Max Absorbance C12: " + str(max(lycopene['C12Ioana']*4.3/3.6)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['C12Ioana'] == max(lycopene['C12Ioana'])].tolist()[0] + 400))

ax2.set_ylim(0, 2)
ax2.set_xlim(400, 540)
ax2.text(380, 2, r'(b)', family="serif",fontsize = 50)
ax2.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax2.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax2.axvline(474,  ymin=0,  ymax= 0.76, color='k')
ax2.text(473, 1.54,r'$\lambda_{max}=$474$nm$', family="serif", fontsize=27)
ax2.set_title(r'"Plasmids C" Lycopene (15$m$M Ara)', fontsize = 40, family = 'serif')
ax2.legend(prop={"size":26, "family": "serif"}, loc='upper left')
ax2.grid()
plt.savefig(f"{images_dir}/LycopeneC15Ara.png", bbox_inches="tight", dpi=100)
# Out:
# Max Absorbance C2: 1.0273 Max $\lambda_{nm}$: 474
# Max Absorbance C5: 0.8273626126126125 Max $\lambda_{nm}$: 474
# Max Absorbance C8: 0.7792519083969466 Max $\lambda_{nm}$: 474
# Max Absorbance C11: 0.7055685714285714 Max $\lambda_{nm}$: 474
# Max Absorbance C3: 0.8839366666666667 Max $\lambda_{nm}$: 474
# Max Absorbance C6: 0.6792656249999999 Max $\lambda_{nm}$: 474
# Max Absorbance C9: 0.5803805555555555 Max $\lambda_{nm}$: 474
# Max Absorbance C12: 1.50715 Max $\lambda_{nm}$: 474

# %%
plt.rc('xtick', labelsize=25)    # fontsize of the tick labels
plt.rc('ytick', labelsize=25)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"

fig = plt.figure(figsize=(35,30))
#
ax1 = plt.subplot(321)
ax1.plot(lycopene['WL (nm)'], lycopene['A12'], ' ',color='k', marker='o', markersize=12,markerfacecolor="k",markevery=2, label = "Negative control 'A'")
ax1.plot(lycopene['WL (nm)'], lycopene['D2']*4.3/2.44, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "0 IPTG")
print(r"Max Absorbance D2: " + str(max(lycopene['D2']*4.3/2.44)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['D2'] == max(lycopene['D2'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['D5']*4.3/2.07, ' ',color='k', marker='o', markersize=12,markerfacecolor="gold",markevery=2, label = r"10$\mu$ IPTG")
print(r"Max Absorbance D5: " + str(max(lycopene['D5']*4.3/2.07)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['D5'] == max(lycopene['D5'])].tolist()[0] + 400))

ax1.plot(lycopene['WL (nm)'], lycopene['D8Ioana']*4.3/3.9, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkviolet",markevery=2, label = r"100$\mu$ IPTG")
print(r"Max Absorbance D8: " + str(max(lycopene['D8Ioana']*4.3/3.9)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['D8Ioana'] == max(lycopene['D8Ioana'])].tolist()[0] + 400))

#ax1.plot(lycopene['WL (nm)'], lycopene['D11']/, ' ',color='k', marker='o', markersize=12,markerfacecolor="springgreen",markevery=2, label = r"1$m$ IPTG")
#print(r"Max Absorbance D11: " + str(max(lycopene['D11'])) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['D11'] == max(lycopene['D11'])].tolist()[0] + 400))

ax1.set_ylim(0, 4)
ax1.set_xlim(400,540)
ax1.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax1.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax1.text(380, 4, r'(c)', family="serif",fontsize = 50)
ax1.axvline(474,  ymin=0,  ymax= 0.64, color='k')
ax1.text(473, 2.6,r'$\lambda_{max}=$474$nm$', family="serif", fontsize=27)
ax1.set_title(r'"Plasmids D"  Lycopene (1.5$m$M Ara) ', fontsize =40, family = 'serif')
ax1.legend(prop={"size":26, "family": "serif"}, loc='upper left')
ax1.grid()
plt.savefig(f"{images_dir}/LycopeneD1_5Ara.png", bbox_inches="tight", dpi=100)
#
fig = plt.figure(figsize=(35,30))
ax2 = plt.subplot(322)
ax2.plot(lycopene['WL (nm)'], lycopene['A12'], ' ',color='k', marker='o', markersize=12,markerfacecolor="k",markevery=2, label = "Negative control 'A'")
ax2.plot(lycopene['WL (nm)'], lycopene['D3']*4.3/3.3, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "0 IPTG")
print(r"Max Absorbance D3: " + str(max(lycopene['D3']*4.3/3.3)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['D3'] == max(lycopene['D3'])].tolist()[0] + 400))

ax2.plot(lycopene['WL (nm)'], lycopene['D6']*4.3/0.93, ' ',color='k', marker='o', markersize=12,markerfacecolor="gold",markevery=2, label = r"10$\mu$ IPTG")
print(r"Max Absorbance D6: " + str(max(lycopene['D6']*4.3/0.93)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['D6'] == max(lycopene['D6'])].tolist()[0] + 400))

ax2.plot(lycopene['WL (nm)'], lycopene['D9']*4.3/2.3, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkviolet",markevery=2, label = r"100$\mu$ IPTG")
print(r"Max Absorbance D9: " + str(max(lycopene['D9']*4.3/2.3)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['D9'] == max(lycopene['D9'])].tolist()[0] + 400))

ax2.plot(lycopene['WL (nm)'], lycopene['D12Ioana']*4.3/3.71, ' ',color='k', marker='o', markersize=12,markerfacecolor="springgreen",markevery=2, label = r"1$m$ IPTG")
print(r"Max Absorbance D12Ioana: " + str(max(lycopene['D12Ioana']*4.3/3.71)) + r' Max $\lambda_{nm}$: ' + str(lycopene.index[lycopene['D12Ioana'] == max(lycopene['D12Ioana'])].tolist()[0] + 400))

ax2.set_ylim(0, 2)
ax2.set_xlim(400, 540)
ax2.text(380, 2, r'(d)', family="serif",fontsize = 50)
ax2.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax2.axvline(474,  ymin=0,  ymax= 0.74, color='k')
ax2.text(473, 1.5,r'$\lambda_{max}=$474$nm$', family="serif", fontsize=27)
ax2.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax2.set_title(r'"Plasmids D" Lycopene (15$m$M Ara)', fontsize = 40, family = 'serif')
ax2.legend(prop={"size":26, "family": "serif"}, loc='upper left')
ax2.grid()

plt.savefig(f"{images_dir}/LycopeneD15Ara.png", bbox_inches="tight", dpi=100)
# Out:
# Max Absorbance D2: 0.8113606557377049 Max $\lambda_{nm}$: 474
# Max Absorbance D5: 1.5278502415458939 Max $\lambda_{nm}$: 474
# Max Absorbance D8: 2.456182051282051 Max $\lambda_{nm}$: 474
# Max Absorbance D3: 0.4530636363636364 Max $\lambda_{nm}$: 474
# Max Absorbance D6: 0.8794193548387097 Max $\lambda_{nm}$: 474
# Max Absorbance D9: 0.8080260869565217 Max $\lambda_{nm}$: 474
# Max Absorbance D12Ioana: 1.415522911051213 Max $\lambda_{nm}$: 474

# %%
plt.rc('xtick', labelsize=25)    # fontsize of the tick labels
plt.rc('ytick', labelsize=25)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"

fig = plt.figure(figsize=(35,30))
#
ax1 = plt.subplot(321)
#ax1.plot(BetaCarotene['WL (nm)'], BetaCarotene['E2'], ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "0 IPTG")
#print(r"Max Absorbance E2: " + str(max(BetaCarotene['E2'])) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['E2'] == max(BetaCarotene['E2'])].tolist()[0] + 400))
ax1.plot(lycopene['WL (nm)'], lycopene['A12'], ' ',color='k', marker='o', markersize=12,markerfacecolor="k",markevery=2, label = "Negative control 'A'")
ax1.plot(BetaCarotene['WL (nm)'], BetaCarotene['E5']*4.3/1.7, ' ',color='k', marker='o', markersize=12,markerfacecolor="gold",markevery=2, label = r"10$\mu$ IPTG")
print(r"Max Absorbance E5: " + str(max(BetaCarotene['E5']*4.3/1.7)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['E5'] == max(BetaCarotene['E5'])].tolist()[0] + 400))

ax1.plot(BetaCarotene['WL (nm)'], BetaCarotene['E8Ioana']*4.3, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkviolet",markevery=2, label = r"100$\mu$ IPTG")
print(r"Max Absorbance E8Ioana: " + str(max(BetaCarotene['E8Ioana']*4.3)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['E8Ioana'] == max(BetaCarotene['E8Ioana'])].tolist()[0] + 400))

#ax1.plot(BetaCarotene['WL (nm)'], BetaCarotene['E11'], ' ',color='k', marker='o', markersize=12,markerfacecolor="springgreen",markevery=2, label = r"1$m$ IPTG")
#print(r"Max Absorbance E11: " + str(max(BetaCarotene['E11'])) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['E11'] == max(BetaCarotene['E11'])].tolist()[0] + 400))

ax1.set_ylim(0, 2)
ax1.set_xlim(400,540)
ax1.text(380, 2, r'(e)', family="serif",fontsize = 50)
ax1.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax1.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax1.axvline(453,  ymin=0,  ymax= 0.72, color='k')
ax1.text(452, 1.48,r'$\lambda_{max}=$453$nm$', family="serif", fontsize=27)
ax1.set_title(r'"Plasmids E" $\beta$-Carotene (1.5$m$M Ara) ', fontsize =40, family = 'serif')
ax1.legend(prop={"size":26, "family": "serif"})
ax1.grid()
plt.savefig(f"{images_dir}/CaroteneE1_5Ara.png", bbox_inches="tight", dpi=100)
#
fig = plt.figure(figsize=(35,30))
ax2 = plt.subplot(322)
ax2.plot(lycopene['WL (nm)'], lycopene['A12'], ' ',color='k', marker='o', markersize=12,markerfacecolor="k",markevery=2, label = "Negative control 'A'")
ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['E3']*4.3/2.46, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "0 IPTG")
print(r"Max Absorbance E3: " + str(max(BetaCarotene['E3']*4.3/2.46)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['E3'] == max(BetaCarotene['E3'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['E6']*4.3/3.14, ' ',color='k', marker='o', markersize=12,markerfacecolor="gold",markevery=2, label = r"10$\mu$ IPTG")
print(r"Max Absorbance E6: " + str(max(BetaCarotene['E6']*4.3/3.14)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['E6'] == max(BetaCarotene['E6'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['E9']*4.3/3.04, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkviolet",markevery=2, label = r"100$\mu$ IPTG")
print(r"Max Absorbance E9: " + str(max(BetaCarotene['E9']*4.3/3.04)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['E9'] == max(BetaCarotene['E9'])].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['E12Ioana']*4.3/3.42, ' ',color='k', marker='o', markersize=12,markerfacecolor="springgreen",markevery=2, label = r"1$m$ IPTG")
print(r"Max Absorbance E12Ioana: " + str(max(BetaCarotene['E12Ioana']*4.3/3.42)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['E12Ioana'] == max(BetaCarotene['E12Ioana'])].tolist()[0] + 400))

ax2.set_ylim(0, 2)
ax2.set_xlim(400, 540)
ax2.text(380, 2, r'(f)', family="serif",fontsize = 50)
ax2.set_ylabel(r'Absorbance/OD$_{600nm}$', family="serif",fontsize = 35)
ax2.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax2.axvline(454,  ymin=0,  ymax= 0.3, color='k')
ax2.text(453, 0.6,r'$\lambda_{max}=$454$nm$', family="serif", fontsize=27)
ax2.set_title(r'"Plasmids E" $\beta$-Carotene (15$m$M Ara)', fontsize = 40, family = 'serif')
ax2.legend(prop={"size":26, "family": "serif"})
ax2.grid()

plt.savefig(f"{images_dir}/CaroteneE15Ara.png", bbox_inches="tight", dpi=100)
# Out:
# Max Absorbance E5: 0.5903647058823529 Max $\lambda_{nm}$: 453
# Max Absorbance E8Ioana: 1.4018 Max $\lambda_{nm}$: 453
# Max Absorbance E3: 0.554280487804878 Max $\lambda_{nm}$: 454
# Max Absorbance E6: 0.20514012738853502 Max $\lambda_{nm}$: 400
# Max Absorbance E9: 0.11683552631578947 Max $\lambda_{nm}$: 400
# Max Absorbance E12Ioana: 0.09932748538011696 Max $\lambda_{nm}$: 451

# %%
plt.rc('xtick', labelsize=25)    # fontsize of the tick labels
plt.rc('ytick', labelsize=25)    # fontsize of the tick labels
plt.rcParams["font.family"] = "serif"

fig = plt.figure(figsize=(35,30))
#
ax1 = plt.subplot(321)
ax1.plot(lycopene['WL (nm)'], lycopene['A12'], ' ',color='k', marker='o', markersize=12,markerfacecolor="k",markevery=2, label = "Negative control 'A'")
ax1.plot(BetaCarotene['WL (nm)'], BetaCarotene['F2']*4.3/4.5, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "0 IPTG")
print(r"Max Absorbance F2: " + str(max(BetaCarotene['F2']*4.3/4.5)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['F2'] == max(BetaCarotene['F2'])].tolist()[0] + 400))

ax1.plot(BetaCarotene['WL (nm)'], BetaCarotene['F5']*4.3/4.42, ' ',color='k', marker='o', markersize=12,markerfacecolor="gold",markevery=2, label = r"10$\mu$ IPTG")
print(r"Max Absorbance F5: " + str(max(BetaCarotene['F5']*4.3/4.42)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['F5'] == max(BetaCarotene['F5'])].tolist()[0] + 400))

ax1.plot(BetaCarotene['WL (nm)'], BetaCarotene['F8Ioana']*4.3/4, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkviolet",markevery=2, label = r"100$\mu$ IPTG")
print(r"Max Absorbance F8Ioana: " + str(max(BetaCarotene['F8Ioana']*4.3/4)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['F8Ioana'] == max(BetaCarotene['F8Ioana'])].tolist()[0] + 400))

ax1.plot(BetaCarotene['WL (nm)'], BetaCarotene['F11']*4.3/4.03, ' ',color='k', marker='o', markersize=12,markerfacecolor="springgreen",markevery=2, label = r"1$m$ IPTG")
print(r"Max Absorbance F11: " + str(max(BetaCarotene['F11']*4.3/4.03)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['F11'] == max(BetaCarotene['F11'])].tolist()[0] + 400))
import matplotlib.ticker as ticker

ax1.set_ylim(0, 2)
ax1.set_xlim(400,540)
ax1.text(380, 2, r'(g)', family="serif",fontsize = 50)
ax1.set_ylabel(r'Absorbance/OD$_{600m}$', family="serif",fontsize = 35)
ax1.axvline(474,  ymin=0,  ymax= 0.69, color='k')
ax1.text(473, 1.4,r'$\lambda_{max}=$474$nm$', family="serif", fontsize=27)
ax1.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
#ax1.set_yticks(np.arange(0, 2.4, 0.4))


ax1.set_title(r'"Plasmids F" $\beta$-Carotene (1.5$m$M Ara) ', fontsize =40, family = 'serif')
ax1.legend(prop={"size":26, "family": "serif"}, loc='upper left')
ax1.grid()
plt.savefig(f"{images_dir}/CaroteneF1_5Ara.png", bbox_inches="tight", dpi=100)
#
fig = plt.figure(figsize=(35,30))
ax2 = plt.subplot(322)
ax2.plot(lycopene['WL (nm)'], lycopene['A12'], ' ',color='k', marker='o', markersize=12,markerfacecolor="k",markevery=2, label = "Negative control 'A'")
ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['F3']*4.3/3.3, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkturquoise",markevery=2, label = "0 IPTG")
print(r"Max Absorbance F3: " + str(max(BetaCarotene['F3']*4.3/3.3)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['F3']/3.3 == max(BetaCarotene['F3']/3.3)].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['F6']*4.3/3.1, ' ',color='k', marker='o', markersize=12,markerfacecolor="gold",markevery=2, label = r"10$\mu$ IPTG")
print(r"Max Absorbance F6: " + str(max(BetaCarotene['F6']*4.3/3.1)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['F6']/3.1 == max(BetaCarotene['F6']/3.1)].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['F9']*4.3/3.24, ' ',color='k', marker='o', markersize=12,markerfacecolor="darkviolet",markevery=2, label = r"100$\mu$ IPTG")
print(r"Max Absorbance F9: " + str(max(BetaCarotene['F9']*4.3/3.24)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['F9']/3.24 == max(BetaCarotene['F9']/3.24)].tolist()[0] + 400))

ax2.plot(BetaCarotene['WL (nm)'], BetaCarotene['F12Ioanax1']*4.3/3.7, ' ',color='k', marker='o', markersize=12,markerfacecolor="springgreen",markevery=2, label = r"1$m$ IPTG")
print(r"Max Absorbance F12Ioanax1: " + str(max(BetaCarotene['F12Ioanax1']*4.3/3.7)) + r' Max $\lambda_{nm}$: ' + str(BetaCarotene.index[BetaCarotene['F12Ioanax1']/3.7 == max(BetaCarotene['F12Ioanax1']/3.7)].tolist()[0] + 400))


ax2.set_xlim(400, 540)
ax2.set_ylim(0, 3)
ax2.set_ylabel(r'Absorbance/OD$_{600m}$', family="serif",fontsize = 35)
ax2.text(380, 3, r'(h)', family="serif",fontsize = 50)
#ax2.set_yticks(np.arange(0, 2.4, 0.4))
ax2.axvline(454,  ymin=0,  ymax= 0.74, color='k')
ax2.text(453, 2.3,r'$\lambda_{max}=$454$nm$', family="serif", fontsize=27)
ax2.set_xlabel(r'$\lambda_{nm}$', family="serif",fontsize = 35)
ax2.axvline(474,  ymin=0,  ymax= 0.21, color='k')
ax2.text(473, 0.7,r'$\lambda_{max}=$474$nm$', family="serif", fontsize=27)
ax2.set_title(r'"Plasmids F" $\beta$-Carotene (15$m$M Ara)', fontsize = 40, family = 'serif')
ax2.legend(prop={"size":26, "family": "serif"})
ax2.grid()
plt.savefig(f"{images_dir}/CaroteneF15Ara.png", bbox_inches="tight", dpi=100)
# Out:
# Max Absorbance F2: 0.6872355555555555 Max $\lambda_{nm}$: 474
# Max Absorbance F5: 0.6485022624434389 Max $\lambda_{nm}$: 474
# Max Absorbance F8Ioana: 1.1051 Max $\lambda_{nm}$: 474
# Max Absorbance F11: 1.3221166253101735 Max $\lambda_{nm}$: 474
# Max Absorbance F3: 0.6046060606060606 Max $\lambda_{nm}$: 474
# Max Absorbance F6: 0.5549774193548387 Max $\lambda_{nm}$: 474
# Max Absorbance F9: 0.5948333333333333 Max $\lambda_{nm}$: 474
# Max Absorbance F12Ioanax1: 2.168827027027027 Max $\lambda_{nm}$: 454
